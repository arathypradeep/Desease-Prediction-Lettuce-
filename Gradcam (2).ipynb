# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.applications.vgg16 import VGG16,preprocess_input, decode_predictions
from keras.preprocessing import image as keras_image

# %%
# Load VGG16 pre-trained on ImageNet without the top layer(classification layer)
base_model = VGG16(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
# Freeze all the layers in the base model
for layer in base_model.layers:
  layer.trainable = False

# %%
# Create custom layers for our new classification task
x = Flatten()(base_model.output)
x = Dense(1024, activation='relu')(x)
predictions = Dense(4, activation='softmax')(x)

# %%
# Combine the original model with the new layers
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
from skimage import io
from PIL import Image

# %%
X=[]
Y=[]
base_path='/content/gdrive/My Drive/lettuce'
source_path=base_path
for child in os.listdir(source_path):
  print(child)
  sub_path = os.path.join(source_path, child)
  bsub_path = os.path.join(base_path, child)
  if os.path.isdir(sub_path):
    for data_file in os.listdir(sub_path):
      Qry = Image.open(os.path.join(sub_path, data_file))
      Qry = Qry.convert("RGB")
      Qry = np.array(Qry.resize((224,224)))
      Qry = Qry.reshape([224,224,3])
      flist=np.array(Qry)
      X.append(flist)
      Y.append(child)
# Out:
# -P
# -N
# FN
# -K

# %%
images_arr = np.asarray(X)
images_arr = images_arr.astype('float32')
images_arr = images_arr / np.max(images_arr)

# %%
from sklearn.preprocessing import LabelBinarizer
labelBinarizer = LabelBinarizer()
y=labelBinarizer.fit_transform(Y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(images_arr,y,test_size=0.2,random_state=42,stratify=y)

# %%
# Compile the model before fitting
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model on your new dataset
model.fit(X_train, y_train, epochs=30, validation_data=(X_test,y_test))
# Out:
# Epoch 1/30
# 32/32 [==============================] - 32s 562ms/step - loss: 1.0645 - accuracy: 0.7139 - val_loss: 0.2084 - val_accuracy: 0.8760
# Epoch 2/30
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0566 - accuracy: 0.9749 - val_loss: 0.0758 - val_accuracy: 0.9680
# Epoch 3/30
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0105 - accuracy: 0.9980 - val_loss: 0.0351 - val_accuracy: 0.9760
# Epoch 4/30
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9720
# Epoch 5/30
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9680
# Epoch 6/30
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9720
# Epoch 7/30
# 32/32 [==============================] - 6s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9680
# Epoch 8/30
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9680
# Epoch 9/30
# 32/32 [==============================] - 6s 178ms/step - loss: 9.3282e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9720
# Epoch 10/30
# 32/32 [==============================] - 6s 185ms/step - loss: 8.1000e-04 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9680
# Epoch 11/30
# 32/32 [==============================] - 6s 179ms/step - loss: 7.2096e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9720
# Epoch 12/30
# 32/32 [==============================] - 6s 181ms/step - loss: 6.1967e-04 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9800
# Epoch 13/30
# 32/32 [==============================] - 6s 186ms/step - loss: 5.4364e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9800
# Epoch 14/30
# 32/32 [==============================] - 6s 183ms/step - loss: 4.8732e-04 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9720
# Epoch 15/30
# 32/32 [==============================] - 6s 186ms/step - loss: 4.2522e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9720
# Epoch 16/30
# 32/32 [==============================] - 6s 184ms/step - loss: 3.7481e-04 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9760
# Epoch 17/30
# 32/32 [==============================] - 6s 182ms/step - loss: 3.3960e-04 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9720
# Epoch 18/30
# 32/32 [==============================] - 6s 179ms/step - loss: 3.0233e-04 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9760
# Epoch 19/30
# 32/32 [==============================] - 6s 181ms/step - loss: 2.6853e-04 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9720
# Epoch 20/30
# 32/32 [==============================] - 6s 179ms/step - loss: 2.3942e-04 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9760
# Epoch 21/30
# 32/32 [==============================] - 6s 183ms/step - loss: 2.2855e-04 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9760
# Epoch 22/30
# 32/32 [==============================] - 6s 179ms/step - loss: 1.9513e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9760
# Epoch 23/30
# 32/32 [==============================] - 6s 182ms/step - loss: 1.7942e-04 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9760
# Epoch 24/30
# 32/32 [==============================] - 6s 184ms/step - loss: 1.6413e-04 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9760
# Epoch 25/30
# 32/32 [==============================] - 6s 183ms/step - loss: 1.5004e-04 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9760
# Epoch 26/30
# 32/32 [==============================] - 6s 180ms/step - loss: 1.4281e-04 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9760
# Epoch 27/30
# 32/32 [==============================] - 6s 183ms/step - loss: 1.2944e-04 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9760
# Epoch 28/30
# 32/32 [==============================] - 6s 181ms/step - loss: 1.2117e-04 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9760
# Epoch 29/30
# 32/32 [==============================] - 6s 183ms/step - loss: 1.1241e-04 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9760
# Epoch 30/30
# 32/32 [==============================] - 6s 179ms/step - loss: 1.0500e-04 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9760

# %%
testLoss, testAccuracy = model.evaluate(X_test,y_test)
print("Test Accuracy =", testAccuracy)
# Out:
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0316 - accuracy: 0.9760
# Test Accuracy = 0.9760000109672546

# %%
model.save('dnnVGG16.keras')

# %%
from tensorflow.keras.models import load_model
vgg_model = load_model("dnnVGG16.keras")

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/lettuce/-K/k_1_aug_1.png"

# %%
img = load_img(img_path, target_size=(224, 224,3)) # Load and resize the image

# If you need a NumPy array for further processing
img_array = img_to_array(img)

# Add a batch dimension (optional, depending on your model)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

# %%
# Get the last convolutional layer and the output layer of the model
last_conv_layer = vgg_model.get_layer('block5_conv3') #to get the last convolutional layer 'block5_conv3'-to get this name print model.summary and get the name, copy and paste it here
#Replace with the actual name of the last convolutional layer
classifier_layer_names = [layer.name for layer in vgg_model.layers if 'dense' in layer.name or 'fc' in layer.name]

# %%
# Create a model that maps the input image to the activations of the last conv layer and the output layer
grad_model = tf.keras.models.Model( [vgg_model.inputs], [vgg_model.get_layer('block5_conv3').output,vgg_model.output]) # Model means functional model
 # i want to get ouput as probability

# %%
# Assuming 'grads' should be the gradients of the output with respect to the last conv layer's activations
with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(tf.cast(img_array, tf.float32))  # Forward pass
    loss = predictions[:, 0] # Assuming you want the gradient for the first class

grads = tape.gradient(loss, conv_outputs)

# Compute the mean intensity of the gradient over each feature map
pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

# %%
# Assuming 'grads' should be the gradients of the output with respect to the last conv layer's activations
with tf.GradientTape() as tape:
    last_conv_layer_output, predictions = grad_model(tf.cast(img_array, tf.float32))  # Forward pass, store output of last conv layer
    loss = predictions[:, 0] # Assuming you want the gradient for the first class

grads = tape.gradient(loss, last_conv_layer_output) # Use last_conv_layer_output for gradient calculation

# Compute the mean intensity of the gradient over each feature map
pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

# Multiply each channel in the feature map array by the "importance" of this channel
last_conv_layer_output = last_conv_layer_output[0] # only one image and it is stored in 'last_conv_layer_output[0]'
heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]# multiply it with pool_grads
heatmap = tf.reduce_mean(heatmap, axis=-1)

# %%
# Apply ReLU to the resulting heatmap
heatmap = tf.maximum(heatmap, 0) #to remove -ve values ie.ReLU application

# %%
# Normalize the heatmap
heatmap /= tf.math.reduce_max(heatmap) # to normalize this value for plotting in python

# %%
# Convert the heatmap to numpy array
heatmap = heatmap.numpy() # change it into array

# %%
import cv2
# Resize the heatmap to match the original image size
img = cv2.imread(img_path) # to resize it for superimposing for that heatmap is converte into our image size
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))

# %%
# Convert heatmap to RGB
heatmap = np.uint8(255 * heatmap) # preproceessing applied with max. pixel intensity value 255
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# %%
# Superimpose the heatmap on the original image
superimposed_img = cv2.addWeighted(img, 0.5, heatmap, 0.5, 0)# original image, its significance, heatma image, its significance , constant value ie. alpha*x+ Beta*heatmap+constant

# %%
import matplotlib.pyplot as plt
# Display the original image, heatmap, and the superimposed image
plt.figure(figsize=(12, 6))
plt.subplot(3, 3, 1)
plt.imshow(img)
plt.title('Original Image')

plt.subplot(3, 3, 2)
plt.imshow(heatmap)
plt.title('Grad-CAM Heatmap')

plt.subplot(3, 3, 3)
plt.imshow(superimposed_img)
plt.title('Superimposed Image with Grad-CAM Heatmap')

#Plot. The visualization makes more sense if a symmetrical colorbar is used. to find low and high value
#plt.imshow(heatmap, cmap = 'RdBu', vmin = -heatmap.max(), vmax = heatmap.max())
plt.colorbar()
plt.show()
